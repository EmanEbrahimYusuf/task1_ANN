# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('penguins.csv')
df.head()
# Out:
#   species  bill_length_mm  bill_depth_mm  flipper_length_mm  gender  \
# 0  Adelie            39.1           18.7                181    male
# 1  Adelie            39.5           17.4                186  female
# 2  Adelie            40.3           18.0                195  female
# 3  Adelie            39.6           17.7                186  female
# 4  Adelie            36.7           19.3                193  female
#
#    body_mass_g
# 0         3750
# 1         3800
# 2         3250
# 3         3500
# 4         3450

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
df2= df.drop('species',axis=1)
df2.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  gender  body_mass_g
# 0            39.1           18.7                181    male         3750
# 1            39.5           17.4                186  female         3800
# 2            40.3           18.0                195  female         3250
# 3            39.6           17.7                186  female         3500
# 4            36.7           19.3                193  female         3450

# %%
sns.pairplot(df,hue="species",markers=["o","s","D"])
